# %% [markdown]
# # 1.) Importing Required Libraries for analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data inspection

# %%
data= pd.read_csv("C:/Users/rambo/OneDrive/Desktop/Projects/PYTHON/AirBNB-1.csv")
df=pd.DataFrame(data)
df
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 0       6901257  Entire home/apt           3.0        1.0              strict
# 1       6304928  Entire home/apt           7.0        1.0              strict
# 2       7919400  Entire home/apt           5.0        1.0            moderate
# 3      13418779  Entire home/apt           4.0        1.0            flexible
# 4       3808709  Entire home/apt           2.0        1.0            moderate
# ...         ...              ...           ...        ...                 ...
# 60204   9304836  Entire home/apt           6.0        2.5            flexible
# 60205  17422489     Private room           2.0        1.0              strict
# 60206   6357564  Entire home/apt           2.0        1.0            moderate
# 60207  12957659  Entire home/apt           6.0        2.0              strict
# 60208  11626869  Entire home/apt           3.0        1.0            flexible
#
# ...

# %% [markdown]
# # Total Rows : 60209
# # Total Columns : 11

# %% [markdown]
# # Data Types in my Data : Int , Float and Object

# %%
df.dtypes
# Out:
# id                        int64
# room_type                object
# accommodates            float64
# bathrooms               float64
# cancellation_policy      object
# cleaning_fee             object
# instant_bookable         object
# review_scores_rating    float64
# bedrooms                float64
# beds                    float64
# log_price               float64
# price                   float64
# dtype: object

# %% [markdown]
# # Fist N rows

# %%
#First 5 rows
df.head()
# Out:
#          id        room_type  accommodates  bathrooms cancellation_policy  \
# 0   6901257  Entire home/apt           3.0        1.0              strict
# 1   6304928  Entire home/apt           7.0        1.0              strict
# 2   7919400  Entire home/apt           5.0        1.0            moderate
# 3  13418779  Entire home/apt           4.0        1.0            flexible
# 4   3808709  Entire home/apt           2.0        1.0            moderate
#
#   cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0         True                f                 100.0       1.0   1.0
# 1         True                t                  93.0       3.0   3.0
# 2         True                t                  92.0       1.0   3.0
# 3         True                f                   NaN       2.0   2.0
# 4         True                t                  40.0       0.0   1.0
#
#    log_price  price
# 0   5.010635  150.0
# 1   5.129899  169.0
# 2   4.976734  145.0
# ...

# %% [markdown]
# # Last N rows

# %%
#last 5 rows
df.tail()
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 60204   9304836  Entire home/apt           6.0        2.5            flexible
# 60205  17422489     Private room           2.0        1.0              strict
# 60206   6357564  Entire home/apt           2.0        1.0            moderate
# 60207  12957659  Entire home/apt           6.0        2.0              strict
# 60208  11626869  Entire home/apt           3.0        1.0            flexible
#
#       cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 60204         True                f                 100.0       3.0   3.0
# 60205         True                t                  95.0       1.0   1.0
# 60206        False                f                 100.0       0.0   1.0
# 60207         True                f                  94.0       3.0   3.0
# 60208         True                f                 100.0       1.0   1.0
#
#        log_price  price
# 60204   6.437752  625.0
# ...

# %% [markdown]
# # No.of.Null Values in Each Columns

# %% [markdown]
# ### There are 5 null in room_type , 3 in accommodates,167 in Bathrooms,8 in Cancellation policy, 4 in cleaning fee,0 in instant_bookable, 13601 in review scores,81 in bedrooms,110 in beds,0 in log_price and 0 in Price

# %%
#no.of.null values
df.isnull().sum()
# Out:
# id                          0
# room_type                   5
# accommodates                3
# bathrooms                 167
# cancellation_policy         8
# cleaning_fee                4
# instant_bookable            0
# review_scores_rating    13601
# bedrooms                   81
# beds                      110
# log_price                   0
# price                       0
# dtype: int64

# %% [markdown]
# # Unique Values in Room Types : - Entire home/apt', 'Private room', 'Shared room'

# %%
#room types unique count
df['room_type'].nunique()
# Out:
# 3

# %%
df['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room', nan],
#       dtype=object)

# %% [markdown]
# # Uniques Values in Cancellation Policy :-strict', 'moderate', 'flexible',

# %%
#cancellation policy unique count
df['cancellation_policy'].nunique()
# Out:
# 3

# %%
df['cancellation_policy'].unique()
# Out:
# array(['strict', 'moderate', 'flexible', nan], dtype=object)

# %% [markdown]
# # EDA :- Exploratory Data Analysis

# %% [markdown]
# # Inspecting the Data

# %% [markdown]
# ##  There are 60209 Rows and 11 Columns in This Data

# %%
df.shape
# Out:
# (60209, 11)

# %%
#Checking Null Values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60209 entries, 0 to 60208
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    60209 non-null  int64
#  1   room_type             60204 non-null  object
#  2   accommodates          60206 non-null  float64
#  3   bathrooms             60042 non-null  float64
#  4   cancellation_policy   60201 non-null  object
#  5   cleaning_fee          60205 non-null  object
#  6   instant_bookable      60209 non-null  object
#  7   review_scores_rating  46608 non-null  float64
#  8   bedrooms              60128 non-null  float64
#  9   beds                  60099 non-null  float64
#  10  log_price             60209 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 5.1+ MB

# %% [markdown]
# ## There are Some Null Values in room_type,accommodates,bathrooms,cancellation_policy,cleaning_fee,review_scores_rating,bedrooms,beds,log_price

# %%
df.isnull().sum()
# Out:
# id                          0
# room_type                   5
# accommodates                3
# bathrooms                 167
# cancellation_policy         8
# cleaning_fee                4
# instant_bookable            0
# review_scores_rating    13601
# bedrooms                   81
# beds                      110
# log_price                   0
# dtype: int64

# %% [markdown]
# ## Data Types of each column id-int,room_type-object,accommodates-float64 etc;

# %%
#Data types of Column
df.dtypes
# Out:
# id                        int64
# room_type                object
# accommodates            float64
# bathrooms               float64
# cancellation_policy      object
# cleaning_fee             object
# instant_bookable         object
# review_scores_rating    float64
# bedrooms                float64
# beds                    float64
# log_price               float64
# dtype: object

# %%
# Data Summary
df.describe()
# Out:
#                  id  accommodates     bathrooms  review_scores_rating  \
# count  6.020900e+04  60206.000000  60042.000000          46608.000000
# mean   1.127395e+07      3.153623      1.235935             94.087646
# std    6.080397e+06      2.156921      0.583414              7.814210
# min    3.440000e+02      1.000000      0.000000             20.000000
# 25%    6.278513e+06      2.000000      1.000000             92.000000
# 50%    1.226280e+07      2.000000      1.000000             96.000000
# 75%    1.640707e+07      4.000000      1.000000            100.000000
# max    2.123090e+07     16.000000      8.000000            100.000000
#
#            bedrooms          beds     log_price
# count  60128.000000  60099.000000  60209.000000
# mean       1.266415      1.711426      4.781945
# std        0.852574      1.260071      0.717318
# min        0.000000      0.000000      0.000000
# 25%        1.000000      1.000000      4.317488
# ...

# %%
df.describe(include='all')
# Out:
#                   id        room_type  accommodates     bathrooms  \
# count   6.020900e+04            60204  60206.000000  60042.000000
# unique           NaN                3           NaN           NaN
# top              NaN  Entire home/apt           NaN           NaN
# freq             NaN            33554           NaN           NaN
# mean    1.127395e+07              NaN      3.153623      1.235935
# std     6.080397e+06              NaN      2.156921      0.583414
# min     3.440000e+02              NaN      1.000000      0.000000
# 25%     6.278513e+06              NaN      2.000000      1.000000
# 50%     1.226280e+07              NaN      2.000000      1.000000
# 75%     1.640707e+07              NaN      4.000000      1.000000
# max     2.123090e+07              NaN     16.000000      8.000000
#
#        cancellation_policy cleaning_fee instant_bookable  \
# count                60201        60205            60209
# ...

# %%
df.columns
# Out:
# Index(['id', 'room_type', 'accommodates', 'bathrooms', 'cancellation_policy',
#        'cleaning_fee', 'instant_bookable', 'review_scores_rating', 'bedrooms',
#        'beds', 'log_price'],
#       dtype='object')

# %% [markdown]
# ## There are 3 Types of Cancellation Policy :- Strict,Flexible and Moderate and their count is Below

# %%
df['cancellation_policy'].value_counts()
# Out:
# cancellation_policy
# strict      26395
# flexible    18331
# moderate    15475
# Name: count, dtype: int64

# %% [markdown]
# # There are 3 Types of Room Types :- Entire home/apt,Private room,Shared room and their count is below

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    33554
# Private room       24912
# Shared room         1738
# Name: count, dtype: int64

# %% [markdown]
# # There are Two types of Cleaning Fee :- True and False and Their Count is given Below

# %%
df['cleaning_fee'].value_counts()
# Out:
# cleaning_fee
# True     44165
# False    16040
# Name: count, dtype: int64

# %% [markdown]
# # There are Two Types of Instant bookable :- f and t . Their count is below

# %%
df['instant_bookable'].value_counts()
# Out:
# instant_bookable
# f    44435
# t    15774
# Name: count, dtype: int64

# %% [markdown]
# # There are No duplicates in my Data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Measure Of Central Tendancy :-
# * Mean
# * Median
# * Mode

# %%
print("Mean of the Data")
df.select_dtypes(include=['number']).mean()
# Out:
# Mean of the Data
# id                      1.127395e+07
# accommodates            3.153623e+00
# bathrooms               1.235935e+00
# review_scores_rating    9.408765e+01
# bedrooms                1.266415e+00
# beds                    1.711426e+00
# log_price               4.781945e+00
# dtype: float64

# %%
df.select_dtypes(include=['number']).median()
# Out:
# id                      1.226280e+07
# accommodates            2.000000e+00
# bathrooms               1.000000e+00
# review_scores_rating    9.600000e+01
# bedrooms                1.000000e+00
# beds                    1.000000e+00
# log_price               4.709530e+00
# dtype: float64

# %%
print(f'The mode for Category Data:')
df.select_dtypes(include=['object']).mode()
# Out:
# The mode for Category Data:
#          room_type cancellation_policy cleaning_fee instant_bookable
# 0  Entire home/apt              strict         True                f

# %% [markdown]
# # Measure of Dispersion

# %%
std_deviation = df.std(numeric_only=True)
varience = df.var(numeric_only=True)
range_value = df.max(numeric_only=True)-df.min(numeric_only=True)

print("\nStandard Deviation")
print(std_deviation)
print('\nVarience')
print(varience)
print('\nrange_value')
print(range_value)
# Out:
# Standard Deviation
# id                      6.080397e+06
# accommodates            2.156921e+00
# bathrooms               5.834137e-01
# review_scores_rating    7.814210e+00
# bedrooms                8.525744e-01
# beds                    1.260071e+00
# log_price               7.173180e-01
# dtype: float64
#
# Varience
# id                      3.697123e+13
# accommodates            4.652307e+00
# bathrooms               3.403715e-01
# review_scores_rating    6.106188e+01
# bedrooms                7.268831e-01
# beds                    1.587778e+00
# log_price               5.145452e-01
# dtype: float64
#
# range_value
# id                      2.123056e+07
# accommodates            1.500000e+01
# bathrooms               8.000000e+00
# review_scores_rating    8.000000e+01
# bedrooms                1.000000e+01
# beds                    1.600000e+01
# log_price               7.600402e+00
# dtype: float64

# %% [markdown]
# # Room Types

# %% [markdown]
# ## There are Entire home/apt:33554 rooms , Private room:24912 and Shared room:1738 and 5 are null

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    33554
# Private room       24912
# Shared room         1738
# Name: count, dtype: int64

# %% [markdown]
# ### 5 Null  Values

# %%
df['room_type'].isnull().sum()
# Out:
# 5

# %% [markdown]
# ### Found the mode and Replaced Null with Entire home/apt

# %%
df['room_type'].mode()
# Out:
# 0    Entire home/apt
# Name: room_type, dtype: object

# %%
df['room_type']=df['room_type'].fillna('Entire home/apt')

# %%
df['room_type'].isnull().sum()
# Out:
# 0

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    33559
# Private room       24912
# Shared room         1738
# Name: count, dtype: int64

# %% [markdown]
# # Total Bathrooms For Room Type and Types of Bathrooms

# %%
df['bathrooms'].unique()
# Out:
# array([1. , 1.5, 2. , 0. , 2.5, 3. , 0.5, 4.5, 5. , 4. , 3.5, 5.5, 7.5,
#        6. , 8. , 7. , 6.5])

# %%
df.head()
# Out:
#          id        room_type  accommodates  bathrooms cancellation_policy  \
# 0   6901257  Entire home/apt           3.0        1.0              strict
# 1   6304928  Entire home/apt           7.0        1.0              strict
# 2   7919400  Entire home/apt           5.0        1.0            moderate
# 3  13418779  Entire home/apt           4.0        1.0            flexible
# 4   3808709  Entire home/apt           2.0        1.0            moderate
#
#   cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0         True                f                 100.0       1.0   1.0
# 1         True                t                  93.0       3.0   3.0
# 2         True                t                  92.0       1.0   3.0
# 3         True                f                   NaN       2.0   2.0
# 4         True                t                  40.0       0.0   1.0
#
#    log_price
# 0   5.010635
# 1   5.129899
# 2   4.976734
# 3   6.620073
# 4   4.744932

# %%
df['bathrooms'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## There 43828 Bathroom for Entire home/apt , 28052 for Private Room and Shared Room has 2321

# %%
df.groupby('room_type')['bathrooms'].sum().reset_index()
# Out:
#          room_type  bathrooms
# 0  Entire home/apt    43834.5
# 1     Private room    28052.5
# 2      Shared room     2321.0

# %% [markdown]
# ## There are 47145 single bathrooms

# %%
df.loc[(df['bathrooms']==1)]
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 0       6901257  Entire home/apt           3.0        1.0              strict
# 1       6304928  Entire home/apt           7.0        1.0              strict
# 2       7919400  Entire home/apt           5.0        1.0            moderate
# 3      13418779  Entire home/apt           4.0        1.0            flexible
# 4       3808709  Entire home/apt           2.0        1.0            moderate
# ...         ...              ...           ...        ...                 ...
# 60201  11398816  Entire home/apt           2.0        1.0            moderate
# 60202  20849060  Entire home/apt           2.0        1.0              strict
# 60205  17422489     Private room           2.0        1.0              strict
# 60206   6357564  Entire home/apt           2.0        1.0            moderate
# 60208  11626869  Entire home/apt           3.0        1.0            flexible
#
# ...

# %% [markdown]
# # There are 6466 Double restrooms

# %%
df.loc[(df['bathrooms']==2)]
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 17     14648556     Private room           2.0        2.0              strict
# 40     19813606  Entire home/apt           5.0        2.0              strict
# 52      3530517  Entire home/apt           6.0        2.0            flexible
# 68     19247305  Entire home/apt           6.0        2.0              strict
# 75     15956956  Entire home/apt           2.0        2.0              strict
# ...         ...              ...           ...        ...                 ...
# 60179  12693458  Entire home/apt           6.0        2.0            moderate
# 60185  19139234  Entire home/apt           4.0        2.0              strict
# 60193  18460988  Entire home/apt           4.0        2.0              strict
# 60198   4003436  Entire home/apt           6.0        2.0            flexible
# 60207  12957659  Entire home/apt           6.0        2.0              strict
#
# ...

# %% [markdown]
# ## There are 863 triple bathrooms

# %%
df.loc[(df['bathrooms']==3)]
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 104    14900814  Entire home/apt           9.0        3.0            moderate
# 213    17330389  Entire home/apt           8.0        3.0              strict
# 216    13616847  Entire home/apt           6.0        3.0              strict
# 254    15146022  Entire home/apt          10.0        3.0              strict
# 443    20955156  Entire home/apt          10.0        3.0            moderate
# ...         ...              ...           ...        ...                 ...
# 59995   6758180  Entire home/apt           6.0        3.0            flexible
# 60000  20572606  Entire home/apt           8.0        3.0              strict
# 60005  17510868  Entire home/apt           4.0        3.0            flexible
# 60040  18444334  Entire home/apt           6.0        3.0              strict
# 60176  13622647  Entire home/apt           5.0        3.0              strict
#
# ...

# %% [markdown]
# # There are 237 (four) bathrooms

# %%
df.loc[(df['bathrooms']==4)]
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 347    20773540  Entire home/apt           8.0        4.0            moderate
# 357     6473307     Private room           2.0        4.0              strict
# 1145    8868841  Entire home/apt          10.0        4.0              strict
# 1557   11069291  Entire home/apt          13.0        4.0              strict
# 2257   13230911     Private room           3.0        4.0              strict
# ...         ...              ...           ...        ...                 ...
# 57688   8353634  Entire home/apt           8.0        4.0            flexible
# 58227  12176070     Private room           3.0        4.0              strict
# 60058  12055084      Shared room           4.0        4.0              strict
# 60137  11378048  Entire home/apt          15.0        4.0              strict
# 60144    409582  Entire home/apt           8.0        4.0              strict
#
# ...

# %% [markdown]
# # There are 58 (Five Bathrooms in a Room )

# %%
df.loc[(df['bathrooms']==5)].shape[0]
# Out:
# 58

# %%
df.loc[(df['bathrooms']==5)].head()
# Out:
#             id        room_type  accommodates  bathrooms cancellation_policy  \
# 279   13309996     Private room           2.0        5.0              strict
# 2386  19032930  Entire home/apt          10.0        5.0              strict
# 3065   9865262  Entire home/apt           8.0        5.0            moderate
# 4807  12537513  Entire home/apt          16.0        5.0              strict
# 4871  19485309  Entire home/apt          12.0        5.0            moderate
#
#      cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 279         False                f                   NaN       1.0   5.0
# 2386         True                t                 100.0       4.0   4.0
# 3065        False                f                  98.0       3.0   6.0
# 4807        False                t                  98.0       7.0  15.0
# 4871         True                f                  93.0       5.0   6.0
#
#       log_price
# 279    5.220356
# 2386   7.467371
# ...

# %% [markdown]
# ## There are 17 (Six Bathrooms)

# %%
df.loc[(df['bathrooms']==6)].shape[0]
# Out:
# 17

# %%
df.loc[(df['bathrooms']==6)].head()
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 4060   15603889  Entire home/apt          16.0        6.0              strict
# 13433  17142458  Entire home/apt          14.0        6.0            moderate
# 13466   1958765  Entire home/apt          16.0        6.0              strict
# 17478  17016258  Entire home/apt          16.0        6.0              strict
# 18144   1682282  Entire home/apt          16.0        6.0              strict
#
#       cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 4060          True                f                   NaN       7.0  14.0
# 13433         True                f                  92.0       6.0   8.0
# 13466         True                f                   NaN       8.0  16.0
# 17478         True                f                   NaN       9.0  16.0
# 18144         True                f                 100.0       0.0   1.0
#
#        log_price
# 4060    6.906755
# ...

# %% [markdown]
# ## There are 7 (Seven Bathrooms for eachroom type)

# %%
df.loc[(df['bathrooms']==7)].shape[0]
# Out:
# 7

# %%
df.loc[(df['bathrooms']==7)]
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 6952   13300964  Entire home/apt          16.0        7.0              strict
# 14981   9769485  Entire home/apt          12.0        7.0              strict
# 27807  19746819  Entire home/apt           8.0        7.0              strict
# 33147   1446537  Entire home/apt          16.0        7.0            flexible
# 48273  16693777  Entire home/apt          16.0        7.0            moderate
# 52810   5204710  Entire home/apt          16.0        7.0            flexible
# 53745   9859888  Entire home/apt          16.0        7.0              strict
#
#       cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 6952          True                f                  96.0       8.0  14.0
# 14981         True                f                   NaN       6.0   8.0
# 27807        False                f                   NaN       4.0   5.0
# ...

# %% [markdown]
# ## There are 37 (Eight Bathrooms for each room type)

# %%
df.loc[(df['bathrooms']==8)].shape[0]
# Out:
# 37

# %%
df.loc[(df['bathrooms']==8)].head()
# Out:
#              id    room_type  accommodates  bathrooms cancellation_policy  \
# 6076   17880992  Shared room           2.0        8.0              strict
# 8140   13451442  Shared room           4.0        8.0            flexible
# 8290    4041806  Shared room           1.0        8.0            flexible
# 8384   13511680  Shared room           1.0        8.0            flexible
# 11109  10707519  Shared room           1.0        8.0            flexible
#
#       cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 6076          True                f                   NaN       1.0   2.0
# 8140         False                t                  94.0       1.0   4.0
# 8290          True                t                  95.0       1.0   1.0
# 8384          True                t                  97.0       1.0   1.0
# 11109        False                f                   NaN       1.0   4.0
#
#        log_price
# 6076    3.401197
# 8140    3.295837
# 8290    3.988984
# ...

# %%
df['accommodates'].unique()
# Out:
# array([ 3.,  7.,  5.,  4.,  2.,  6.,  8.,  1.,  9., 10., 16., nan, 11.,
#        12., 14., 13., 15.])

# %% [markdown]
# # There are 136844 accommodates in Entire home/apt,49465 in Private room and 3545 in shared room

# %%
df.groupby('room_type')['accommodates'].sum().reset_index()
# Out:
#          room_type  accommodates
# 0  Entire home/apt      136857.0
# 1     Private room       49465.0
# 2      Shared room        3545.0

# %% [markdown]
# # Total Bedrooms For Each Type of Room

# %% [markdown]
# ## There are 48860 bedrooms for Entire home/apt	 , 25543 bedrooms for Private room	 and Shared room has 1738

# %%
df.groupby('room_type')['bedrooms'].sum().reset_index()
# Out:
#          room_type  bedrooms
# 0  Entire home/apt   48860.0
# 1     Private room   25543.0
# 2      Shared room    1738.0

# %% [markdown]
# # Total Beds For Each room Type

# %% [markdown]
# # There are 70751 beds in Entire home/apt,29088 beds in Private room and shared room has 3008

# %%
df.groupby('room_type')['beds'].sum().reset_index()
# Out:
#          room_type     beds
# 0  Entire home/apt  70751.0
# 1     Private room  29088.0
# 2      Shared room   3008.0

# %% [markdown]
# # Total  Rooms

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    33554
# Private room       24912
# Shared room         1738
# Name: count, dtype: int64

# %% [markdown]
# # Accommodates with 1 are 7695

# %%
df.loc[(df['accommodates']==1)]
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 33     10994968     Private room           1.0        NaN            moderate
# 37      4209927     Private room           1.0        1.0              strict
# 47      5117069     Private room           1.0        1.0            flexible
# 64      5806687  Entire home/apt           1.0        1.0            flexible
# 77      6972777     Private room           1.0        1.0            flexible
# ...         ...              ...           ...        ...                 ...
# 60157  18159407     Private room           1.0        1.0            flexible
# 60164  16677358     Private room           1.0        1.0            moderate
# 60174  15597200     Private room           1.0        1.0            flexible
# 60175  13616798      Shared room           1.0        1.0              strict
# 60188   4164931     Private room           1.0        1.0              strict
#
# ...

# %% [markdown]
# # Accommodates with 2 are 25901

# %%
df.loc[(df['accommodates'] == 2)]
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 4       3808709  Entire home/apt           2.0        1.0            moderate
# 5      12422935     Private room           2.0        1.0              strict
# 7      13971273  Entire home/apt           2.0        1.0            moderate
# 8        180792     Private room           2.0        1.0            moderate
# 9       5385260     Private room           2.0        1.0            moderate
# ...         ...              ...           ...        ...                 ...
# 60199  19828873     Private room           2.0        1.0            moderate
# 60201  11398816  Entire home/apt           2.0        1.0            moderate
# 60202  20849060  Entire home/apt           2.0        1.0              strict
# 60205  17422489     Private room           2.0        1.0              strict
# 60206   6357564  Entire home/apt           2.0        1.0            moderate
#
# ...

# %% [markdown]
# # Accommodates with 3 are 6286

# %%
df.loc[(df['accommodates']==3)]
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 0       6901257  Entire home/apt           3.0        1.0              strict
# 6      11825529  Entire home/apt           3.0        1.0            moderate
# 28       851978  Entire home/apt           3.0        1.0            flexible
# 29      4734170     Private room           3.0        1.0              strict
# 65     16474211  Entire home/apt           3.0        1.0            moderate
# ...         ...              ...           ...        ...                 ...
# 60177  19058675     Private room           3.0        1.5            flexible
# 60178  15221305  Entire home/apt           3.0        1.0            flexible
# 60181   1398616  Entire home/apt           3.0        1.0            moderate
# 60187  16552108  Entire home/apt           3.0        1.0            flexible
# 60208  11626869  Entire home/apt           3.0        1.0            flexible
#
# ...

# %% [markdown]
# # Bathrooms That are more than 1

# %%
df.loc[(df['bathrooms']>1)]
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 11     17423675  Entire home/apt           4.0        1.5              strict
# 13      2658946  Entire home/apt           6.0        1.5              strict
# 15      6226658     Private room           2.0        1.5            moderate
# 17     14648556     Private room           2.0        2.0              strict
# 21     16679342     Private room           2.0        1.5              strict
# ...         ...              ...           ...        ...                 ...
# 60193  18460988  Entire home/apt           4.0        2.0              strict
# 60198   4003436  Entire home/apt           6.0        2.0            flexible
# 60203   8555250  Entire home/apt           4.0        1.5            flexible
# 60204   9304836  Entire home/apt           6.0        2.5            flexible
# 60207  12957659  Entire home/apt           6.0        2.0              strict
#
# ...

# %% [markdown]
# # Review scores greater than 85

# %%
df.loc[(df['review_scores_rating']>85)]
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 0       6901257  Entire home/apt           3.0        1.0              strict
# 1       6304928  Entire home/apt           7.0        1.0              strict
# 2       7919400  Entire home/apt           5.0        1.0            moderate
# 5      12422935     Private room           2.0        1.0              strict
# 6      11825529  Entire home/apt           3.0        1.0            moderate
# ...         ...              ...           ...        ...                 ...
# 60204   9304836  Entire home/apt           6.0        2.5            flexible
# 60205  17422489     Private room           2.0        1.0              strict
# 60206   6357564  Entire home/apt           2.0        1.0            moderate
# 60207  12957659  Entire home/apt           6.0        2.0              strict
# 60208  11626869  Entire home/apt           3.0        1.0            flexible
#
# ...

# %% [markdown]
# # Greater than 2 bedrooms and greater than 2 accommodates and greater than 2 bathrooms

# %%
df.loc[(df['accommodates']>2) & (df['bathrooms']>2) & (df['bedrooms']>2)]
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 62     11712092  Entire home/apt           9.0        2.5            flexible
# 104    14900814  Entire home/apt           9.0        3.0            moderate
# 153    20199218  Entire home/apt           7.0        2.5              strict
# 213    17330389  Entire home/apt           8.0        3.0              strict
# 216    13616847  Entire home/apt           6.0        3.0              strict
# ...         ...              ...           ...        ...                 ...
# 60144    409582  Entire home/apt           8.0        4.0              strict
# 60170   2503000  Entire home/apt          14.0        5.0            flexible
# 60172  17699634  Entire home/apt           6.0        3.5              strict
# 60176  13622647  Entire home/apt           5.0        3.0              strict
# 60204   9304836  Entire home/apt           6.0        2.5            flexible
#
# ...

# %% [markdown]
# # Display the Flexible Cancellation policy  and Private room and Review should be Greater than 85

# %%
df.loc[(df['cancellation_policy']=='flexible') & (df['room_type']=='Private room') & (df['review_scores_rating']>85)]
# Out:
#              id     room_type  accommodates  bathrooms cancellation_policy  \
# 54     17078757  Private room           2.0        1.0            flexible
# 70      4285537  Private room           2.0        1.0            flexible
# 83     18524434  Private room           1.0        1.0            flexible
# 87     20761244  Private room           4.0        1.0            flexible
# 107    16490513  Private room           2.0        1.0            flexible
# ...         ...           ...           ...        ...                 ...
# 60126  12344949  Private room           2.0        1.0            flexible
# 60133   1356710  Private room           2.0        1.0            flexible
# 60140  20663936  Private room           1.0        1.0            flexible
# 60153  13058423  Private room           2.0        1.0            flexible
# 60174  15597200  Private room           1.0        1.0            flexible
#
# ...

# %%
df.head(2)
# Out:
#         id        room_type  accommodates  bathrooms cancellation_policy  \
# 0  6901257  Entire home/apt           3.0        1.0              strict
# 1  6304928  Entire home/apt           7.0        1.0              strict
#
#   cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0         True                f                 100.0       1.0   1.0
# 1         True                t                  93.0       3.0   3.0
#
#    log_price
# 0   5.010635
# 1   5.129899

# %%
df['review_scores_rating'].mean()
# Out:
# 94.08764589769997

# %%
7.8
# Out:
# 7.814210030340204

# %%
df['review_scores_rating'].median()
# Out:
# 96.0

# %% [markdown]
# #  1. Univariate Analysis:
# * Univariate analysis refers to the analysis of a single variable. The goal is to understand the distribution, spread, and central tendency of that variable.

# %% [markdown]
# # Histogram

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,8))
plt.hist(df['review_scores_rating'])
ax=plt.gca()
for bar in ax.patches:
    x=bar.get_x()+bar.get_width()/2
    y=bar.get_height()
    ax.text(x,y,f'{y:.0f}',ha='center',va='bottom',fontsize=10)
plt.title('Review_Scores_Rating',fontsize=16)
plt.xlabel('Ratings',fontsize=12)
plt.ylabel('Count of ratings',fontsize=12)
plt.savefig('Review_Scores.png',format='png')
plt.show()

# %% [markdown]
# # CountPlot

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(8,6))
color=['red','blue','green']
sns.countplot(data=df,x='room_type',hue='room_type',palette=color)
ax=plt.gca()
for bar in ax.patches:
    x=bar.get_x()+bar.get_width()/2
    y=bar.get_height()
    ax.text(x,y,f'{y:.0f}',ha='center',va='bottom',fontsize=10)

#Adding title and labels
plt.title('Count of Rooms',fontsize=16)
plt.xlabel('Room types',fontsize=14)
plt.ylabel('Count of Rooms',fontsize=12)
plt.savefig('countplot.png',format='png')
plt.show()

# %% [markdown]
# # Total  Bathrooms

# %%
df.groupby('room_type')['bathrooms'].sum().reset_index()
# Out:
#          room_type  bathrooms
# 0  Entire home/apt    43828.0
# 1     Private room    28052.5
# 2      Shared room     2321.0

# %% [markdown]
# # Bar Plot

# %%
sns.set(style='darkgrid')
grouped=df.groupby('room_type')['bathrooms'].sum().reset_index()
plt.figure(figsize=(10,8))
color=['yellow','red','black']
sns.barplot(data=grouped,x='bathrooms',y='room_type',hue='room_type',palette=color,orient='h')
ax=plt.gca() #Get Current axes
for bar in ax.patches:
    x = bar.get_width()  # For horizontal, we use width for x position
    y = bar.get_y() + bar.get_height() / 2  # For horizontal, we use y position
    ax.text(x, y, f'{x:.0f}', ha='left', va='center', fontsize=14)

plt.title("Count Of Bathrooms For Each room types",fontsize=16)
plt.xlabel('Count of Bathrooms',fontsize=14)
plt.ylabel('Room Types',fontsize=14)
plt.savefig('barplot.png',format='png')
plt.show()

# %% [markdown]
# # 2. Bivarient Analysis:
# * Bivariate analysis refers to the analysis of two variables to explore the relationship between them.

# %% [markdown]
# # Total Reviews Rating by Rooms

# %%
df.head(2)
# Out:
#         id        room_type  accommodates  bathrooms cancellation_policy  \
# 0  6901257  Entire home/apt           3.0        1.0              strict
# 1  6304928  Entire home/apt           7.0        1.0              strict
#
#   cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0         True                f                 100.0       1.0   1.0
# 1         True                t                  93.0       3.0   3.0
#
#    log_price
# 0   5.010635
# 1   5.129899

# %% [markdown]
# ## Pie Chart

# %%
room_type = df.groupby('room_type')['review_scores_rating'].mean()
#Create Piechart
plt.figure(figsize=(8,8))
plt.pie(room_type,labels=room_type.index,
       autopct='%1.1f%%',startangle=120,
       colors=sns.color_palette('pastel'))
plt.title('review_scores_rating for Rooms',fontsize=16)
plt.savefig('Review Scores Rating for Rooms.png',format='png')
plt.show()

# %% [markdown]
# # Log Price Vs Review Scores

# %%
df.head()
# Out:
#          id        room_type  accommodates  bathrooms cancellation_policy  \
# 0   6901257  Entire home/apt           3.0        1.0              strict
# 1   6304928  Entire home/apt           7.0        1.0              strict
# 2   7919400  Entire home/apt           5.0        1.0            moderate
# 3  13418779  Entire home/apt           4.0        1.0            flexible
# 4   3808709  Entire home/apt           2.0        1.0            moderate
#
#   cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0         True                f                 100.0       1.0   1.0
# 1         True                t                  93.0       3.0   3.0
# 2         True                t                  92.0       1.0   3.0
# 3         True                f                   NaN       2.0   2.0
# 4         True                t                  40.0       0.0   1.0
#
#    log_price
# 0   5.010635
# 1   5.129899
# 2   4.976734
# 3   6.620073
# 4   4.744932

# %% [markdown]
# ## line Chart

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x='review_scores_rating', y='log_price', errorbar=None)
plt.title('Log Price Vs Review Scores',fontsize=16)
plt.xlabel('Review Scores',fontsize=12)
plt.ylabel('Log Price',fontsize=12)
plt.savefig('log_price vs Review_price.png',format='png')
plt.show()

# %%
df.head(3)
# Out:
#         id        room_type  accommodates  bathrooms cancellation_policy  \
# 0  6901257  Entire home/apt           3.0        1.0              strict
# 1  6304928  Entire home/apt           7.0        1.0              strict
# 2  7919400  Entire home/apt           5.0        1.0            moderate
#
#   cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0         True                f                 100.0       1.0   1.0
# 1         True                t                  93.0       3.0   3.0
# 2         True                t                  92.0       1.0   3.0
#
#    log_price
# 0   5.010635
# 1   5.129899
# 2   4.976734

# %% [markdown]
# # Heat Map

# %%
numeric_data = df[['accommodates','bathrooms','review_scores_rating','bedrooms','beds','log_price']]

corr_matrix = numeric_data.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',
           fmt='.2f',linewidth=0.5)

plt.title('Correlation of heat map of Numeric Variables',fontsize=14)
plt.savefig('Heat map.png',format='png')
plt.show()

# %%
df.head()
# Out:
#          id        room_type  accommodates  bathrooms cancellation_policy  \
# 0   6901257  Entire home/apt           3.0        1.0              strict
# 1   6304928  Entire home/apt           7.0        1.0              strict
# 2   7919400  Entire home/apt           5.0        1.0            moderate
# 3  13418779  Entire home/apt           4.0        1.0            flexible
# 4   3808709  Entire home/apt           2.0        1.0            moderate
#
#   cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0         True                f                 100.0       1.0   1.0
# 1         True                t                  93.0       3.0   3.0
# 2         True                t                  92.0       1.0   3.0
# 3         True                f                   NaN       2.0   2.0
# 4         True                t                  40.0       0.0   1.0
#
#    log_price
# 0   5.010635
# 1   5.129899
# 2   4.976734
# 3   6.620073
# 4   4.744932

# %%
sns.kdeplot(data=df,x='accommodates',fill=True,color='blue')
plt.show()
